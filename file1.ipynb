# %% [markdown]
# # CSV DATA FORMAT

# %%
#SWETHA JENIFER S_225229142
#PML_LAB1_16-12-2022

# %%
#reading csv file
import pandas as pd
data=pd.read_csv('lab1.csv')
data
# Out:
#    rollno name  m1  m2  m3  total
# 0       1    a  90  90  90    270
# 1       2    b  80  80  80    240
# 2       3    c  70  70  70    210

# %%
data1=data[['m1','m2','m3','total']]
data1
# Out:
#    m1  m2  m3  total
# 0  90  90  90    270
# 1  80  80  80    240
# 2  70  70  70    210

# %%
#Visualizing data files using graphs
import seaborn as sns
g=sns.pairplot(data1,kind="reg")

# %%
from matplotlib import pyplot as plt
#ploting data with line graph
data.plot()
#bargraph
data.plot(kind="bar")
#histogram
data.plot.hist()
#scatterplot
data.plot.scatter(x='rollno',y='total');
#scatterplot using color,size and shape
data.plot.scatter(x='rollno',y='total',marker='*',s=100,color='purple');
#peichart
fig=plt.figure(figsize=(5,5))
rno=[1,2,3]
tot=[270,240,210]
plt.pie(rno,labels=tot)
plt.show()
